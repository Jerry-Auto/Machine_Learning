# %% [markdown]
# # Import packages

# %%
# Numerical Operations
import math
import numpy as np

# Reading/Writing Data
import pandas as pd
import os
import csv

# For Progress Bar
from tqdm import tqdm

# Pytorch
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split

# Matplotlib
import matplotlib.pyplot as plt

# Optuna
import optuna

# For plotting learning curve
from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# # Some Utility Functions
#
# You do not need to modify this part.

# %%
def same_seed(seed):
    '''Fixes random number generator seeds for reproducibility.'''
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

def train_valid_split(data_set, valid_ratio, seed):
    '''Split provided training data into training set and validation set'''
    valid_set_size = int(valid_ratio * len(data_set))
    train_set_size = len(data_set) - valid_set_size
    train_set, valid_set = random_split(data_set, [train_set_size, valid_set_size], generator=torch.Generator().manual_seed(seed))
    return np.array(train_set), np.array(valid_set)

def predict(test_loader, model, device):
    model.eval() # Set your model to evaluation mode.
    preds = []
    for x in tqdm(test_loader):
        x = x.to(device)
        with torch.no_grad():
            pred = model(x)
            preds.append(pred.detach().cpu())
    preds = torch.cat(preds, dim=0).numpy()
    return preds

# %% [markdown]
# # Dataset

# %%
class CovidDataset(Dataset):
    def __init__(self, x, y=None):
        if y is None:
            self.y = y
        else:
            self.y = torch.FloatTensor(y)
        self.x = torch.FloatTensor(x)
    
    def __getitem__(self, idx):
        if self.y is None:
            return self.x[idx]
        else:
            return self.x[idx], self.y[idx]
    
    def __len__(self):
        return len(self.x)

# %% [markdown]
# # Neural Network Model
#
# Try out different model architectures by modifying the class below. (You could tune config['layer'] to try)

# %%
class My_Model(nn.Module):
    def __init__(self, input_dim):
        super(My_Model, self).__init__()
        # TODO: modify model's structure, be aware of dimensions.
        self.layers = nn.Sequential(
            nn.Linear(input_dim, config['layer'][0]),
            nn.ReLU(),
            nn.Linear(config['layer'][0], config['layer'][1]),
            nn.ReLU(),
            nn.Linear(config['layer'][1], 1)
        )

    def forward(self, x):
        x = self.layers(x)
        x = x.squeeze(1) # (B, 1) -> (B)
        return x

# %% [markdown]
# # Feature Selection
#
# Choose features you deem useful by modifying the function below.

# %%
from sklearn.feature_selection import SelectKBest, f_regression

def select_feat(train_data, valid_data, test_data, no_select_all=True):
    '''Selects useful features to perform regression'''
    global config
    y_train, y_valid = train_data[:,-1], valid_data[:,-1]
    raw_x_train, raw_x_valid, raw_x_test = train_data[:,:-1], valid_data[:,:-1], test_data

    if not no_select_all:
        feat_idx = list(range(raw_x_train.shape[1]))
    else:
        # Feature selection
        k = config['k']
        selector = SelectKBest(score_func=f_regression, k=k)
        result = selector.fit(train_data[:, :-1], train_data[:,-1])
        idx = np.argsort(result.scores_)[::-1]
        feat_idx = list(np.sort(idx[:k]))

    return raw_x_train[:,feat_idx], raw_x_valid[:,feat_idx], raw_x_test[:,feat_idx], y_train, y_valid

# %% [markdown]
# # Training Loop

# %%
def trainer(train_loader, valid_loader, model, config, device):
    
    # Define your loss function, do not modify this.
    criterion = nn.MSELoss(reduction='mean') 
    
    # Define your optimization algorithm.
    if config['optim'] == 'SGD':
        if config['no_momentum']:
            optimizer = torch.optim.SGD(model.parameters(), lr=config['learning_rate'], weight_decay=config['weight_decay'])     
        else:
            optimizer = torch.optim.SGD(model.parameters(), lr=config['learning_rate'], momentum=config['momentum'], weight_decay=config['weight_decay'])     
    elif config['optim'] == 'Adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=config['learning_rate'], weight_decay=config['weight_decay'])
        
    # Writer of tensoboard.
    writer = SummaryWriter() 

        
    if not os.path.isdir('./models'):
        os.mkdir('./models') # Create directory of saving models.

    n_epochs, best_loss, step, early_stop_count = config['n_epochs'], math.inf, 0, 0

    for epoch in range(n_epochs):
        model.train() # Set your model to train mode.
        loss_record = []
        
        # 如果你在kaggle上运行，可以注释掉大部分的打印函数，并将train_pbar注释掉，令 x,y in train_loader，因为kaggle上打印太多可能会报错。
        # tqdm is a package to visualize your training progress.
        #train_pbar = tqdm(train_loader, position=0, leave=True)
        #for x, y in train_pbar:
        for x, y in train_loader:
            optimizer.zero_grad()               # Set gradient to zero.
            x, y = x.to(device), y.to(device)   # Move your data to device.
            pred = model(x)
            loss = criterion(pred, y)
            loss.backward()                     # Compute gradient(backpropagation).
            optimizer.step()                    # Update parameters.
            step += 1
            loss_record.append(loss.detach().item())

            # Display current epoch number and loss on tqdm progress bar.
            #train_pbar.set_description(f'Epoch [{epoch+1}/{n_epochs}]')
            #train_pbar.set_postfix({'loss': loss.detach().item()})

        mean_train_loss = sum(loss_record)/len(loss_record)

        model.eval() # Set your model to evaluation mode.
        loss_record = []
        for x, y in valid_loader:
            x, y = x.to(device), y.to(device)
            with torch.no_grad():
                pred = model(x)
                loss = criterion(pred, y)

            loss_record.append(loss.item())

        mean_valid_loss = sum(loss_record)/len(loss_record)        
        
        #if epoch % 100 == 0:
        #    print(f'Epoch [{epoch+1}/{n_epochs}]: Train loss: {mean_train_loss:.4f}, Valid loss: {mean_valid_loss:.4f}')

        if not config['no_tensorboard']:
            writer.add_scalar('Loss/train', mean_train_loss, step)
            writer.add_scalar('Loss/valid', mean_valid_loss, step)

        if mean_valid_loss < best_loss:
            best_loss = mean_valid_loss
            
            # 一轮实验中保存 K 折交叉验证中单折表现最好的模型
            if len(valid_scores):
                if best_loss < min(valid_scores):
                    torch.save(model.state_dict(), config['save_path']) # Save your best model
                    #print(f'Epoch [{epoch+1}/{n_epochs}]: Train loss: {mean_train_loss:.4f}, Valid loss: {mean_valid_loss:.4f}')
                    print('Saving model with loss {:.3f}...'.format(best_loss))
            else:
                torch.save(model.state_dict(), config['save_path']) # Save your best model
                #print(f'Epoch [{epoch+1}/{n_epochs}]: Train loss: {mean_train_loss:.4f}, Valid loss: {mean_valid_loss:.4f}')
                print('Saving model with loss {:.3f}...'.format(best_loss))
                
            early_stop_count = 0
        else:
            early_stop_count += 1

        if early_stop_count >= config['early_stop']:
            print('Best loss {:.3f}...'.format(best_loss))
            print('\nModel is not improving, so we halt the training session.')
            break
    return best_loss

# %% [markdown]
# # Save predictions

# %%
def save_pred(preds, file):
    ''' Save predictions to specified file '''
    with open(file, 'w') as fp:
        writer = csv.writer(fp)
        writer.writerow(['id', 'tested_positive'])
        for i, p in enumerate(preds):
            writer.writerow([i, p])

# %% [markdown]
# # Start training!
#
# config contains hyper-parameters for training and the path to save your model.
#
# `objective()` is used for automatic parameter tuning, but you could set `AUTO_TUNE_PARAM` `False` to avoid it.

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

config = {
    'seed': 5201314,      # Your seed number, you can pick your lucky number. :)
    'k': 16,              # Select k features
    'layer': [16, 16],
    'optim': 'SGD',
    'momentum': 0.7,
    'valid_ratio': 0.2,   # validation_size = train_size * valid_ratio
    'n_epochs': 100000,    # Number of epochs.
    'batch_size': 300,
    'learning_rate': 1e-5,
    'weight_decay': 1e-5,
    'early_stop': 5000,        # If model has not improved for this many consecutive epochs, stop training.
    'save_path': './models/model.ckpt',  # Your model will be saved here.
    'no_select_all': True,    # Whether to use all features.
    'no_momentum': True,      # Whether to use momentum
    'no_normal': True,        # Whether to normalize data
    'no_k_cross': False,      # Whether to use K-fold cross validation
    'no_save': False,         # Whether to save model parameters
    'no_tensorboard': False,  # Whether to write tensorboard
} 

# 设置 k-fold 中的 k，这里是根据 valid_ratio 设定的
k = int(1 / config['valid_ratio'])

 # Set seed for reproducibility
same_seed(config['seed'])

training_data, test_data = pd.read_csv('./covid_train.csv').values, pd.read_csv('./covid_test.csv').values
    
num_valid_samples = len(training_data) // k
np.random.shuffle(training_data)
valid_scores = []  # 记录 valid_loss

def objective(trial):
    if trial != None:
        print('\nNew trial here')
        # 定义需要调优的超参数空间
        config['learning_rate'] = trial.suggest_float('lr', 1e-6, 1e-3)
        config['batch_size'] = trial.suggest_categorical('batch_size', [1024])
        config['k'] = trial.suggest_int('k_feats', 16, 32)
        config['layer'][0] = config['k']
    
    # 打印所需的超参数
    print(f'''hyper-parameter: 
        optimizer: {config['optim']},
        lr: {config['learning_rate']}, 
        batch_size: {config['batch_size']}, 
        k: {config['k']}, 
        layer: {config['layer']}''')
    
    global valid_scores
    # 每次 trial 初始化 valid_scores，可以不初始化，通过 trial * k + fold 来访问当前 trial 的 valid_score，
    # 这样可以让 trainer() 保存 trials 中最好的模型参数，但这并不意味着该参数对应的 k-fold validation loss 最低。
    valid_scores = []

    for fold in range(k):
        # Data split
        valid_data = training_data[num_valid_samples * fold:
                                num_valid_samples * (fold + 1)]
        train_data = np.concatenate((
            training_data[:num_valid_samples * fold],
            training_data[num_valid_samples * (fold + 1):]))

        # Normalization
        if not config['no_normal']:
            train_mean = np.mean(train_data[:, 35:-1], axis=0)  # 前 35 列为 one-hot vector，我并没有对他们做 normalization，可以自行设置
            train_std = np.std(train_data[:, 35:-1], axis=0)
            train_data[:, 35:-1] -= train_mean
            train_data[:, 35:-1] /= train_std
            valid_data[:, 35:-1] -= train_mean
            valid_data[:, 35:-1] /= train_std
            test_data[:, 35:] -= train_mean
            test_data[:, 35:] /= train_std

        x_train, x_valid, x_test, y_train, y_valid = select_feat(train_data, valid_data, test_data, config['no_select_all'])
        
        train_dataset, valid_dataset, test_dataset = CovidDataset(x_train, y_train), \
                                                CovidDataset(x_valid, y_valid), \
                                                CovidDataset(x_test)

        # Pytorch data loader loads pytorch dataset into batches.
        train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True, pin_memory=True)
        valid_loader = DataLoader(valid_dataset, batch_size=config['batch_size'], shuffle=True, pin_memory=True)
        test_loader = DataLoader(test_dataset, batch_size=config['batch_size'], shuffle=False, pin_memory=True)
        
        model = My_Model(input_dim=x_train.shape[1]).to(device) # put your model and data on the same computation device.
        valid_score = trainer(train_loader, valid_loader, model, config, device)
        valid_scores.append(valid_score)
        
        if not config['no_k_cross']:
            break
            
        if valid_score > 2:
            print(f'在第{fold+1}折上欠拟合') # 提前终止，减少计算资源
            break       
        
    print(f'valid_scores: {valid_scores}')
    
    if trial != None:
        return np.average(valid_scores)
    else:
        return x_test, test_loader


AUTO_TUNE_PARAM = False  # Whether to tune parameters automatically

if AUTO_TUNE_PARAM:
    # 使用Optuna库进行超参数搜索
    n_trials = 10  # 设置试验数量
    print(f'AUTO_TUNE_PARAM: {AUTO_TUNE_PARAM}\nn_trials: {n_trials}')
    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=n_trials)

    # 输出最优的超参数组合和性能指标
    print('Best hyperparameters: {}'.format(study.best_params))
    print('Best performance: {:.4f}'.format(study.best_value))
else:
    # 注意，只有非自动调参时才进行了predict，节省一下计算资源
    print(f'You could set AUTO_TUNE_PARAM True to tune parameters automatically.\nAUTO_TUNE_PARAM: {AUTO_TUNE_PARAM}')
    x_test, test_loader = objective(None)
    model = My_Model(input_dim=x_test.shape[1]).to(device)
    model.load_state_dict(torch.load(config['save_path']))
    preds = predict(test_loader, model, device)
    save_pred(preds, 'submission.csv')
# Out:
# You could set AUTO_TUNE_PARAM True to tune parameters automatically.
# AUTO_TUNE_PARAM: False
# hyper-parameter:
#         optimizer: SGD,
#         lr: 1e-05,
#         batch_size: 300,
#         k: 16,
#         layer: [16, 16]
# Saving model with loss 276.648...
# Saving model with loss 163.336...
# Saving model with loss 92.717...
# Saving model with loss 51.773...
# Saving model with loss 29.716...
# Saving model with loss 20.284...
# Saving model with loss 16.843...
# Saving model with loss 15.490...
# Saving model with loss 14.912...
# Saving model with loss 14.620...
# Saving model with loss 14.557...
# Saving model with loss 14.231...
# Saving model with loss 14.155...
# Saving model with loss 14.074...
# Saving model with loss 13.907...
# Saving model with loss 13.770...
# Saving model with loss 13.765...
# Saving model with loss 13.515...
# Saving model with loss 13.426...
# Saving model with loss 13.418...
# Saving model with loss 13.206...
# Saving model with loss 13.134...
# Saving model with loss 13.036...
# Saving model with loss 12.957...
# Saving model with loss 12.642...
# Saving model with loss 12.548...
# Saving model with loss 12.431...
# Saving model with loss 12.320...
# Saving model with loss 12.187...
# Saving model with loss 12.014...
# Saving model with loss 12.000...
# Saving model with loss 11.960...
# Saving model with loss 11.824...
# Saving model with loss 11.717...
# Saving model with loss 11.566...
# Saving model with loss 11.523...
# Saving model with loss 11.358...
# Saving model with loss 11.335...
# Saving model with loss 11.254...
# Saving model with loss 11.229...
# Saving model with loss 11.041...
# Saving model with loss 10.981...
# Saving model with loss 10.930...
# Saving model with loss 10.834...
# Saving model with loss 10.804...
# Saving model with loss 10.686...
# Saving model with loss 10.644...
# Saving model with loss 10.538...
# Saving model with loss 10.397...
# Saving model with loss 10.353...
# Saving model with loss 10.273...
# Saving model with loss 10.206...
# Saving model with loss 10.093...
# Saving model with loss 9.989...
# Saving model with loss 9.979...
# Saving model with loss 9.868...
# Saving model with loss 9.785...
# Saving model with loss 9.701...
# Saving model with loss 9.623...
# Saving model with loss 9.555...
# Saving model with loss 9.404...
# Saving model with loss 9.331...
# Saving model with loss 9.309...
# Saving model with loss 9.218...
# Saving model with loss 9.190...
# Saving model with loss 9.136...
# Saving model with loss 9.052...
# Saving model with loss 9.052...
# Saving model with loss 9.012...
# Saving model with loss 8.854...
# Saving model with loss 8.799...
# Saving model with loss 8.769...
# Saving model with loss 8.707...
# Saving model with loss 8.655...
# Saving model with loss 8.601...
# Saving model with loss 8.568...
# Saving model with loss 8.557...
# Saving model with loss 8.457...
# Saving model with loss 8.446...
# Saving model with loss 8.368...
# Saving model with loss 8.360...
# Saving model with loss 8.355...
# Saving model with loss 8.308...
# Saving model with loss 8.200...
# Saving model with loss 8.125...
# Saving model with loss 8.110...
# Saving model with loss 8.101...
# Saving model with loss 7.999...
# Saving model with loss 7.867...
# Saving model with loss 7.855...
# Saving model with loss 7.717...
# Saving model with loss 7.630...
# Saving model with loss 7.620...
# Saving model with loss 7.604...
# Saving model with loss 7.522...
# Saving model with loss 7.442...
# Saving model with loss 7.413...
# Saving model with loss 7.356...
# Saving model with loss 7.309...
# Saving model with loss 7.298...
# Saving model with loss 7.124...
# Saving model with loss 7.120...
# Saving model with loss 7.099...
# Saving model with loss 7.027...
# Saving model with loss 7.018...
# Saving model with loss 6.935...
# Saving model with loss 6.836...
# Saving model with loss 6.810...
# Saving model with loss 6.675...
# Saving model with loss 6.564...
# Saving model with loss 6.515...
# Saving model with loss 6.497...
# Saving model with loss 6.461...
# Saving model with loss 6.444...
# Saving model with loss 6.320...
# Saving model with loss 6.273...
# Saving model with loss 6.265...
# Saving model with loss 6.228...
# Saving model with loss 6.225...
# Saving model with loss 6.152...
# Saving model with loss 6.063...
# Saving model with loss 6.006...
# Saving model with loss 5.981...
# Saving model with loss 5.966...
# Saving model with loss 5.926...
# Saving model with loss 5.840...
# Saving model with loss 5.785...
# Saving model with loss 5.728...
# Saving model with loss 5.711...
# Saving model with loss 5.705...
# Saving model with loss 5.683...
# Saving model with loss 5.679...
# Saving model with loss 5.668...
# Saving model with loss 5.536...
# Saving model with loss 5.516...
# Saving model with loss 5.468...
# Saving model with loss 5.426...
# Saving model with loss 5.378...
# Saving model with loss 5.354...
# Saving model with loss 5.335...
# Saving model with loss 5.302...
# Saving model with loss 5.287...
# Saving model with loss 5.258...
# Saving model with loss 5.258...
# Saving model with loss 5.145...
# Saving model with loss 5.102...
# Saving model with loss 5.033...
# Saving model with loss 5.024...
# Saving model with loss 4.993...
# Saving model with loss 4.976...
# Saving model with loss 4.935...
# Saving model with loss 4.924...
# Saving model with loss 4.920...
# Saving model with loss 4.905...
# Saving model with loss 4.898...
# Saving model with loss 4.833...
# Saving model with loss 4.795...
# Saving model with loss 4.771...
# Saving model with loss 4.715...
# Saving model with loss 4.692...
# Saving model with loss 4.633...
# Saving model with loss 4.625...
# Saving model with loss 4.614...
# Saving model with loss 4.612...
# Saving model with loss 4.495...
# Saving model with loss 4.484...
# Saving model with loss 4.461...
# Saving model with loss 4.376...
# Saving model with loss 4.329...
# Saving model with loss 4.315...
# Saving model with loss 4.314...
# Saving model with loss 4.296...
# Saving model with loss 4.295...
# Saving model with loss 4.277...
# Saving model with loss 4.274...
# Saving model with loss 4.233...
# Saving model with loss 4.206...
# Saving model with loss 4.182...
# Saving model with loss 4.166...
# Saving model with loss 4.152...
# Saving model with loss 4.110...
# Saving model with loss 4.100...
# Saving model with loss 4.063...
# Saving model with loss 4.052...
# Saving model with loss 4.022...
# Saving model with loss 3.981...
# Saving model with loss 3.926...
# Saving model with loss 3.918...
# Saving model with loss 3.855...
# Saving model with loss 3.823...
# Saving model with loss 3.781...
# Saving model with loss 3.743...
# Saving model with loss 3.725...
# Saving model with loss 3.695...
# Saving model with loss 3.692...
# Saving model with loss 3.646...
# Saving model with loss 3.598...
# Saving model with loss 3.583...
# Saving model with loss 3.582...
# Saving model with loss 3.542...
# Saving model with loss 3.513...
# Saving model with loss 3.506...
# Saving model with loss 3.487...
# Saving model with loss 3.468...
# Saving model with loss 3.444...
# Saving model with loss 3.441...
# Saving model with loss 3.415...
# Saving model with loss 3.379...
# Saving model with loss 3.314...
# Saving model with loss 3.268...
# Saving model with loss 3.255...
# Saving model with loss 3.233...
# Saving model with loss 3.219...
# Saving model with loss 3.216...
# Saving model with loss 3.185...
# Saving model with loss 3.184...
# Saving model with loss 3.183...
# Saving model with loss 3.180...
# Saving model with loss 3.120...
# Saving model with loss 3.107...
# Saving model with loss 3.091...
# Saving model with loss 3.084...
# Saving model with loss 3.066...
# Saving model with loss 3.046...
# Saving model with loss 3.043...
# Saving model with loss 3.021...
# Saving model with loss 2.947...
# Saving model with loss 2.929...
# Saving model with loss 2.883...
# Saving model with loss 2.872...
# Saving model with loss 2.862...
# Saving model with loss 2.830...
# Saving model with loss 2.820...
# Saving model with loss 2.803...
# Saving model with loss 2.798...
# Saving model with loss 2.770...
# Saving model with loss 2.762...
# Saving model with loss 2.755...
# Saving model with loss 2.726...
# Saving model with loss 2.704...
# Saving model with loss 2.685...
# Saving model with loss 2.677...
# Saving model with loss 2.654...
# Saving model with loss 2.648...
# Saving model with loss 2.624...
# Saving model with loss 2.613...
# Saving model with loss 2.565...
# Saving model with loss 2.548...
# Saving model with loss 2.547...
# Saving model with loss 2.547...
# Saving model with loss 2.504...
# Saving model with loss 2.452...
# Saving model with loss 2.438...
# Saving model with loss 2.424...
# Saving model with loss 2.397...
# Saving model with loss 2.363...
# Saving model with loss 2.360...
# Saving model with loss 2.341...
# Saving model with loss 2.340...
# Saving model with loss 2.336...
# Saving model with loss 2.332...
# Saving model with loss 2.308...
# Saving model with loss 2.273...
# Saving model with loss 2.265...
# Saving model with loss 2.258...
# Saving model with loss 2.168...
# Saving model with loss 2.161...
# Saving model with loss 2.133...
# Saving model with loss 2.133...
# Saving model with loss 2.121...
# Saving model with loss 2.110...
# Saving model with loss 2.109...
# Saving model with loss 2.089...
# Saving model with loss 2.067...
# Saving model with loss 2.064...
# Saving model with loss 2.059...
# Saving model with loss 2.052...
# Saving model with loss 2.043...
# Saving model with loss 2.042...
# Saving model with loss 2.031...
# Saving model with loss 2.018...
# Saving model with loss 2.014...
# Saving model with loss 2.003...
# Saving model with loss 1.989...
# Saving model with loss 1.980...
# Saving model with loss 1.971...
# Saving model with loss 1.964...
# Saving model with loss 1.959...
# Saving model with loss 1.955...
# Saving model with loss 1.952...
# Saving model with loss 1.933...
# Saving model with loss 1.923...
# Saving model with loss 1.917...
# Saving model with loss 1.913...
# Saving model with loss 1.900...
# Saving model with loss 1.895...
# Saving model with loss 1.884...
# Saving model with loss 1.863...
# Saving model with loss 1.858...
# Saving model with loss 1.834...
# Saving model with loss 1.826...
# Saving model with loss 1.825...
# Saving model with loss 1.803...
# Saving model with loss 1.796...
# Saving model with loss 1.782...
# Saving model with loss 1.780...
# Saving model with loss 1.777...
# Saving model with loss 1.754...
# Saving model with loss 1.727...
# Saving model with loss 1.720...
# Saving model with loss 1.716...
# Saving model with loss 1.697...
# Saving model with loss 1.686...
# Saving model with loss 1.682...
# Saving model with loss 1.665...
# Saving model with loss 1.665...
# Saving model with loss 1.658...
# Saving model with loss 1.658...
# Saving model with loss 1.635...
# Saving model with loss 1.626...
# Saving model with loss 1.620...
# Saving model with loss 1.615...
# Saving model with loss 1.594...
# Saving model with loss 1.592...
# Saving model with loss 1.585...
# Saving model with loss 1.584...
# Saving model with loss 1.583...
# Saving model with loss 1.576...
# Saving model with loss 1.573...
# Saving model with loss 1.545...
# Saving model with loss 1.539...
# Saving model with loss 1.537...
# Saving model with loss 1.531...
# Saving model with loss 1.524...
# Saving model with loss 1.493...
# Saving model with loss 1.492...
# Saving model with loss 1.489...
# Saving model with loss 1.484...
# Saving model with loss 1.472...
# Saving model with loss 1.452...
# Saving model with loss 1.451...
# Saving model with loss 1.445...
# Saving model with loss 1.443...
# Saving model with loss 1.428...
# Saving model with loss 1.427...
# Saving model with loss 1.422...
# Saving model with loss 1.415...
# Saving model with loss 1.408...
# Saving model with loss 1.406...
# Saving model with loss 1.400...
# Saving model with loss 1.393...
# Saving model with loss 1.390...
# Saving model with loss 1.388...
# Saving model with loss 1.384...
# Saving model with loss 1.379...
# Saving model with loss 1.376...
# Saving model with loss 1.368...
# Saving model with loss 1.355...
# Saving model with loss 1.343...
# Saving model with loss 1.342...
# Saving model with loss 1.335...
# Saving model with loss 1.328...
# Saving model with loss 1.327...
# Saving model with loss 1.321...
# Saving model with loss 1.320...
# Saving model with loss 1.316...
# Saving model with loss 1.312...
# Saving model with loss 1.304...
# Saving model with loss 1.300...
# Saving model with loss 1.295...
# Saving model with loss 1.292...
# Saving model with loss 1.284...
# Saving model with loss 1.282...
# Saving model with loss 1.277...
# Saving model with loss 1.276...
# Saving model with loss 1.272...
# Saving model with loss 1.271...
# Saving model with loss 1.270...
# Saving model with loss 1.260...
# Saving model with loss 1.259...
# Saving model with loss 1.256...
# Saving model with loss 1.252...
# Saving model with loss 1.246...
# Saving model with loss 1.245...
# Saving model with loss 1.243...
# Saving model with loss 1.238...
# Saving model with loss 1.238...
# Saving model with loss 1.228...
# Saving model with loss 1.226...
# Saving model with loss 1.216...
# Saving model with loss 1.214...
# Saving model with loss 1.211...
# Saving model with loss 1.209...
# Saving model with loss 1.202...
# Saving model with loss 1.200...
# Saving model with loss 1.199...
# Saving model with loss 1.197...
# Saving model with loss 1.196...
# Saving model with loss 1.195...
# Saving model with loss 1.188...
# Saving model with loss 1.187...
# Saving model with loss 1.183...
# Saving model with loss 1.177...
# Saving model with loss 1.176...
# Saving model with loss 1.175...
# Saving model with loss 1.172...
# Saving model with loss 1.172...
# Saving model with loss 1.171...
# Saving model with loss 1.168...
# Saving model with loss 1.163...
# Saving model with loss 1.161...
# Saving model with loss 1.160...
# Saving model with loss 1.156...
# Saving model with loss 1.154...
# Saving model with loss 1.150...
# Saving model with loss 1.149...
# Saving model with loss 1.148...
# Saving model with loss 1.147...
# Saving model with loss 1.141...
# Saving model with loss 1.131...
# Saving model with loss 1.130...
# Saving model with loss 1.129...
# Saving model with loss 1.126...
# Saving model with loss 1.122...
# Saving model with loss 1.119...
# Saving model with loss 1.118...
# Saving model with loss 1.116...
# Saving model with loss 1.112...
# Saving model with loss 1.093...
# Saving model with loss 1.089...
# Saving model with loss 1.082...
# Saving model with loss 1.081...
# Saving model with loss 1.075...
# Saving model with loss 1.074...
# Saving model with loss 1.071...
# Saving model with loss 1.071...
# Saving model with loss 1.066...
# Saving model with loss 1.066...
# Saving model with loss 1.062...
# Saving model with loss 1.050...
# Saving model with loss 1.048...
# Saving model with loss 1.044...
# Saving model with loss 1.043...
# Saving model with loss 1.042...
# Saving model with loss 1.040...
# Saving model with loss 1.040...
# Saving model with loss 1.040...
# Saving model with loss 1.035...
# Saving model with loss 1.024...
# Saving model with loss 1.021...
# Saving model with loss 1.014...
# Saving model with loss 1.012...
# Saving model with loss 1.011...
# Saving model with loss 1.002...
# Saving model with loss 0.999...
# Saving model with loss 0.995...
# Saving model with loss 0.995...
# Saving model with loss 0.994...
# Saving model with loss 0.991...
# Saving model with loss 0.991...
# Saving model with loss 0.986...
# Saving model with loss 0.985...
# Saving model with loss 0.983...
# Saving model with loss 0.983...
# Saving model with loss 0.983...
# Saving model with loss 0.975...
# Saving model with loss 0.973...
# Saving model with loss 0.972...
# Saving model with loss 0.970...
# Saving model with loss 0.968...
# Saving model with loss 0.966...
# Saving model with loss 0.966...
# Saving model with loss 0.965...
# Saving model with loss 0.965...
# Saving model with loss 0.964...
# Saving model with loss 0.959...
# Saving model with loss 0.957...
# Saving model with loss 0.957...
# Saving model with loss 0.951...
# Saving model with loss 0.951...
# Saving model with loss 0.950...
# Saving model with loss 0.947...
# Saving model with loss 0.947...
# Saving model with loss 0.946...
# Saving model with loss 0.945...
# Saving model with loss 0.945...
# Saving model with loss 0.943...
# Saving model with loss 0.943...
# Saving model with loss 0.937...
# Saving model with loss 0.934...
# Saving model with loss 0.934...
# Saving model with loss 0.932...
# Saving model with loss 0.929...
# Saving model with loss 0.925...
# Saving model with loss 0.921...
# Saving model with loss 0.921...
# Saving model with loss 0.920...
# Saving model with loss 0.920...
# Saving model with loss 0.916...
# Saving model with loss 0.912...
# Saving model with loss 0.911...
# Saving model with loss 0.911...
# Saving model with loss 0.910...
# Saving model with loss 0.910...
# Saving model with loss 0.910...
# Saving model with loss 0.909...
# Saving model with loss 0.905...
# Saving model with loss 0.900...
# Saving model with loss 0.900...
# Saving model with loss 0.899...
# Saving model with loss 0.892...
# Saving model with loss 0.891...
# Saving model with loss 0.891...
# Saving model with loss 0.886...
# Saving model with loss 0.884...
# Saving model with loss 0.881...
# Saving model with loss 0.881...
# Saving model with loss 0.881...
# Saving model with loss 0.878...
# Saving model with loss 0.877...
# Saving model with loss 0.876...
# Saving model with loss 0.874...
# Saving model with loss 0.874...
# Saving model with loss 0.872...
# Saving model with loss 0.871...
# Saving model with loss 0.866...
# Best loss 0.866...
#
# Model is not improving, so we halt the training session.
# valid_scores: [0.8657916188240051]
# 100%|██████████| 3/3 [00:00<00:00, 1911.43it/s]

# %% [markdown]
# # Plot learning curves with `tensorboard` (optional)
#
# `tensorboard` is a tool that allows you to visualize your training progress.
#
# If this block does not display your learning curve, please wait for few minutes, and re-run this block. It might take some time to load your logging information.

# %%
# %reload_ext tensorboard
# %tensorboard --logdir=./runs/
# Out:
#       <iframe id="tensorboard-frame-25f8f76e1ebab9a2" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-25f8f76e1ebab9a2");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
